# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Generar datos y graficar
num_points = 30
m, b = 2, 1
lower, upper = 0, 25

x1 = [random.randrange(start=1, stop=9) for i in range(num_points)]
x2 = [random.randrange(start=1, stop=9) for i in range(num_points)]

y1 = [random.randrange(start=lower, stop=m*x+b) for x in x1]
y2 = [random.randrange(start=m*x+b+1, stop=upper) for x in x2]

plt.plot(np.arange(10), m*np.arange(10)+b)
plt.scatter(x1, y1, c='blue')
plt.scatter(x2, y2, c='red')

# %%
#Juntamos los datos generados con su respectiva etiqueta
df = pd.DataFrame(list(zip(x1, y1)), 
               columns =['X', 'Y'])
df2 = pd.DataFrame(list(zip(x2, y2)), 
               columns =['X', 'Y'])
df['L'] = 1
df2['L'] = 0
frames = [df, df2]
result = pd.concat(frames, ignore_index=True)
data = np.asmatrix(result, dtype = 'float64')

# %%
def perceptron(data, num_iter):
    features = data[:, :-1] #las x's y y's
    labels = data[:, -1] #el último elemento es el clasificatorio
    
    # inicializar los w en 0's, agregamos un elemento por el bias
    w = np.zeros(shape=(1, features.shape[1]+1))
    w = np.random.rand(1,3)
    misclassified_ = []
    rate_classified_ = []
    count = 0
    acurracy = 0
    iteractions = 0
    deltas = 0
    #for epoch in range(num_iter):
    while acurracy < 1:
        misclassified = 0
        count = 0
        iteractions = iteractions +1 
        for x, label in zip(features, labels):
            count = count+1
            x = np.insert(x,0,1)
            y = np.dot(w, x.transpose())
            target = 1.0 if (y > 0) else 0.0
            delta = (label.item(0,0) - target)
            
            deltas += pow(delta,2)
            
            if(delta): # mal clasificado
                misclassified += 1
                w += (delta * x )
        rate_classified_.append(1-(misclassified/count))
        misclassified_.append(misclassified)
        acurracy = 1-(misclassified/count)
        
        w0 = w[0][0]
        w1 = w[0][1]
        w2 = w[0][2]
        
        
        py1 = 0
        px1 = -b / w1 
        px2 = 0
        py2 = -b / w2
        m = -(b / w2) / (b / w1) 
        slope = m

        point_1 = (0, -b / w2) 
        point_2 = (-b / w1, 0)
        slope = -(b / w2) / (b / w1)
        
        M = -w1 / w2
        C = -b / w1
        
        
        
        plt.figure()
        plt.plot(np.arange(10), M * np.arange(10) + C)
        
        ##rafica profe
        plot_x = np.arange(10)
        plot_y = -1 / w2 * (w1 * plot_x + w0)
        plt.plot(plot_x,plot_y, color='k', linewidth=2)
        ##
        
        plt.scatter(x1, y1, c='blue')
        plt.scatter(x2, y2, c='red')
        plt.xlabel(("Iteracción: ", iteractions, "Errores: ", misclassified))
        
        print('Iteraction ', iteractions, '- w: ',  w)
        print('Iteraction ', iteractions, '- m: ',  m)
        print('Iteraction ', iteractions, '- misclassified: ',misclassified)        
        print('Iteraction ', iteractions, '- ecm: ',deltas/iteractions)
        print('Iteraction ', iteractions, '- acurracy: ', acurracy)
        print('-----------------------------------------------------')
        
    plt.show()
    return (w, misclassified_, rate_classified_, iteractions, deltas/iteractions)
             
num_iter = 20
w, misclassified_, rate_classified_,iteractions_,ecm_ = perceptron(data, num_iter)
# Out:
# Iteraction  1 - w:  [[ -0.7184809   -3.01371014 -10.31151473]]
# Iteraction  1 - m:  -0.292266482943224
# Iteraction  1 - misclassified:  1
# Iteraction  1 - ecm:  1.0
# Iteraction  1 - acurracy:  0.9833333333333333
# -----------------------------------------------------
# Iteraction  2 - w:  [[  0.2815191   -0.01371014 -11.31151473]]
# Iteraction  2 - m:  -0.0012120520816668516
# Iteraction  2 - misclassified:  3
# Iteraction  2 - ecm:  2.0
# Iteraction  2 - acurracy:  0.95
# -----------------------------------------------------
# Iteraction  3 - w:  [[  1.2815191    2.98628986 -12.31151473]]
# Iteraction  3 - m:  0.2425607181294091
# Iteraction  3 - misclassified:  3
# Iteraction  3 - ecm:  2.3333333333333335
# Iteraction  3 - acurracy:  0.95
# -----------------------------------------------------
# Iteraction  4 - w:  [[  2.2815191    5.98628986 -13.31151473]]
# Iteraction  4 - m:  0.44970763845167405
# Iteraction  4 - misclassified:  3
# Iteraction  4 - ecm:  2.5
# Iteraction  4 - acurracy:  0.95
# -----------------------------------------------------
# Iteraction  5 - w:  [[  3.2815191    8.98628986 -14.31151473]]
# Iteraction  5 - m:  0.627906271443141
# Iteraction  5 - misclassified:  3
# Iteraction  5 - ecm:  2.6
# Iteraction  5 - acurracy:  0.95
# -----------------------------------------------------
# Iteraction  6 - w:  [[  4.2815191   11.98628986 -15.31151473]]
# Iteraction  6 - m:  0.782828483245332
# Iteraction  6 - misclassified:  3
# Iteraction  6 - ecm:  2.6666666666666665
# Iteraction  6 - acurracy:  0.95
# -----------------------------------------------------
# Iteraction  7 - w:  [[  5.2815191   14.98628986 -16.31151473]]
# Iteraction  7 - m:  0.918755253565446
# Iteraction  7 - misclassified:  3
# Iteraction  7 - ecm:  2.7142857142857144
# Iteraction  7 - acurracy:  0.95
# -----------------------------------------------------
# Iteraction  8 - w:  [[ 6.2815191  18.98628986 -9.31151473]]
# Iteraction  8 - m:  2.0390119543813516
# Iteraction  8 - misclassified:  1
# Iteraction  8 - ecm:  2.5
# Iteraction  8 - acurracy:  0.9833333333333333
# -----------------------------------------------------
# Iteraction  9 - w:  [[ 6.2815191  18.98628986 -9.31151473]]
# Iteraction  9 - m:  2.0390119543813516
# Iteraction  9 - misclassified:  0
# Iteraction  9 - ecm:  2.2222222222222223
# Iteraction  9 - acurracy:  1.0
# -----------------------------------------------------

# %%
epochs = np.arange(1, iteractions_+1)
plt.figure()
plt.plot(epochs, misclassified_)
plt.xlabel('iteracciones')
plt.ylabel('mal clasificados')
plt.show()
print(rate_classified_)
print(w)
# Out:
# [0.9833333333333333, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.9833333333333333, 1.0]
# [[ 6.20976449 18.55251665 -9.21811221]]

# %%
#Verificación de parámetros para formula general de recta y = mx + b

b = w[0][0]
w1 = w[0][1]
w2 = w[0][2]


py1 = 0
px1 = -b / w1 if w1 != 0 else 0
px2 = 0
py2 = -b / w2 if w1 != 0 else 0
if((w1 != 0) & (w2 != 0) & ((b / w1) != 0)):
    m = -(b / w2) / (b / w1) 
x = 8
y = ((-(b / w2) / (b / w1))* x + (-b / w2))
print(m,x,y)

print(b,w1,w2)

X = np.arange(10)
M = -w1 / w2
C = -b / w1
print(M,C)
# Out:
# 2.0658658717730773 8 17.20781012091413
# 7.022678855878487 21.307492550620086 -10.314073552283642
# 2.0658658717730773 -0.32958729607412746
